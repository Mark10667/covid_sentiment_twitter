# %% [markdown]
# <h1>Import Libraries
# <h1/>

# %%
# Data source: https://github.com/nytimes/covid-19-data/tree/master/rolling-averages
import numpy as np 
import pandas as pd
from scipy.stats import pearsonr
import plotly
import plotly.graph_objs as go
import plotly.offline as offline
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <h1> NLP setup
# </h1>

# %%
# Regular NLP Package 
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/yinxiuchen/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Pre-trained BERT
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# %%
tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')

# %%
# tokens = tokenizer.encode('it is alright', return_tensors='pt')
# result = model(tokens)
# result.logits
# int(torch.argmax(result.logits))/2-1

def BERT_score(tweet):
    tokens = tokenizer.encode(tweet, return_tensors='pt')
    result = model(tokens)
    return int(torch.argmax(result.logits))/2-1

# %%
# !pip install torch torchvision torchaudio
# !pip install transformers

# %% [markdown]
# <h1>Dataframe Load From BigQuery
# <h1/>

# %%
# Download GCP BigQuery table into a dataframe 

from google.cloud import bigquery

bqclient = bigquery.Client()

# Download a table.
table = bigquery.TableReference.from_string(
    "tweetanalysis-332220.geotweet.tweet"
)
rows = bqclient.list_rows(
    table,
    selected_fields=[
        bigquery.SchemaField("TWEET", "STRING"),
        bigquery.SchemaField("LOCATION", "STRING"),
        bigquery.SchemaField("DATE", "DATE"),
    ],
)
dataframe = rows.to_dataframe(
    # Optionally, explicitly request to use the BigQuery Storage API. As of
    # google-cloud-bigquery version 1.26.0 and above, the BigQuery Storage
    # API is used by default.
    create_bqstorage_client=True,
)

print(dataframe.head())
# Out:
#                                                TWEET LOCATION        DATE
# 0  RT @AuschwitzMuseum: The instrumentalization o...     Iowa  2021-05-26
# 1  ‘What IS this headline’?! Kira Davis DROPS The...     Iowa  2021-05-26
# 2  RT @DanPriceSeattle: One of the biggest myths ...     Iowa  2021-05-26
# 3  RT @mmpadellan: Republicans are AGAINST:  - Th...     Iowa  2021-05-26
# 4  RT @AnthonyMKreis: I have serious questions ab...     Iowa  2021-05-26

# %%
# nltk
dataframe['POLARITY'] = dataframe['TWEET'].apply(lambda t: sid.polarity_scores(t)['compound'])
# BERT
# dataframe['POLARITY'] = dataframe['TWEET'].apply(lambda t: BERT_score(t))

# %%
dataframe.head(10)
# Out:
#                                                TWEET LOCATION        DATE  \
# 0  RT @AuschwitzMuseum: The instrumentalization o...     Iowa  2021-05-26
# 1  ‘What IS this headline’?! Kira Davis DROPS The...     Iowa  2021-05-26
# 2  RT @DanPriceSeattle: One of the biggest myths ...     Iowa  2021-05-26
# 3  RT @mmpadellan: Republicans are AGAINST:  - Th...     Iowa  2021-05-26
# 4  RT @AnthonyMKreis: I have serious questions ab...     Iowa  2021-05-26
# 5  All three of Sioux City's libraries are now op...     Iowa  2021-05-26
# 6  White House calls on World Health Organization...     Iowa  2021-05-26
# 7  RT @GordonGChang: So far, #COVID19 has killed ...     Iowa  2021-05-26
# 8  RT @GordonGChang: Yes, there is a completely r...     Iowa  2021-05-26
# 9  RT @jairsmoya: covid has lasted 3 bad bunny al...     Iowa  2021-05-26
#
#    POLARITY
# 0   -0.9062
# 1   -0.7500
# 2   -0.4404
# 3    0.4767
# 4   -0.7184
# 5    0.4404
# 6    0.0000
# 7   -0.3612
# 8   -0.0240
# 9   -0.5423

# %%
# We need a function to process the dataframe from Bigsql
# 1) filter tweets that contain protection measures first 
# 2) generate each state's average sentiment on that day

def bq_df(df):
    searchfor = ['vaccin', 'Vaccin', 'mask', 'Mask', 'distanc', 'sanitizer', 'WFH']
    df = df.loc[df['TWEET'].str.contains('|'.join(searchfor))]
    
    df = df[["LOCATION", "DATE", "POLARITY"]]

    grouped_df = df.groupby(["DATE", "LOCATION"])
    mean_df = grouped_df.mean()
    mean_df = mean_df.reset_index()
    
    mean_df.rename(columns={"DATE": "date", "LOCATION": "location", "POLARITY": "polarity"}, inplace=True)
        
    return mean_df

# %% [markdown]
# <h1>State - State_id
# <h1/>

# %%
#  build dictionary, i.e. 'DC': 'District of Columbia'
df = pd.read_csv('uscities.csv', delimiter=",")
df_states = df[['state_name', 'state_id']]
dic = pd.Series(df.state_name.values,index=df.state_id).to_dict()

# reverse dictionary to generate State_code column later in maps 
r_dic = {v: k for k, v in dic.items()}

# %% [markdown]
# <h1>Covid Data
# <h1/>

# %%
# cases_avg_per_100k: seven-day rolling average per 100,000 residents

df = pd.read_csv('covid_cases.csv')
df['date']= pd.to_datetime(df['date'])
# extract rows from June 
mask = (df['date'] >= '2021-6-1') & (df['date'] <= '2021-6-30')
df_June = df.loc[mask]
df_June = df_June.sort_values(["state", "date"], ascending=True)
df_June.reset_index()
df_June.head(5)
# Out:
#             date   geoid    state  cases  cases_avg  cases_avg_per_100k  \
# 25093 2021-06-01  USA-01  Alabama    640     211.86                4.32
# 25148 2021-06-02  USA-01  Alabama    553     252.43                5.15
# 25203 2021-06-03  USA-01  Alabama    430     264.43                5.39
# 25258 2021-06-04  USA-01  Alabama    557     311.43                6.35
# 25313 2021-06-05  USA-01  Alabama      0     311.43                6.35
#
#        deaths  deaths_avg  deaths_avg_per_100k
# 25093      10        4.57                 0.09
# 25148      11        4.14                 0.08
# 25203      21        6.86                 0.14
# 25258      10        7.43                 0.15
# 25313       0        7.43                 0.15

# %%
# create df_June_pct_ch that contains pct_ch_case_7_days

notwant2 = ['Guam', 'Northern Mariana Islands', 'Virgin Islands']
df_June_pct_ch = df_June.loc[~df_June['state'].isin(notwant2)]
df_June_pct_ch['cases_pct_ch'] = df_June_pct_ch.groupby('state')['cases_avg_per_100k'].pct_change()
df_June_pct_ch = df_June_pct_ch.reset_index()
df_June_pct_ch = df_June_pct_ch[['state', 'date', 'cases_avg_per_100k', 'cases_pct_ch']]
df_June_pct_ch['pct_ch_case_7_days'] = df_June_pct_ch.groupby('state')['cases_pct_ch'].rolling(min_periods=1, window=7).mean().reset_index(name='pct_ch_case_7_days')['pct_ch_case_7_days']
df_June_pct_ch["State_code"] = df_June_pct_ch["state"].apply(lambda x: r_dic[x])
df_June_pct_ch.head(5)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      state       date  cases_avg_per_100k  cases_pct_ch  pct_ch_case_7_days  \
# 0  Alabama 2021-06-01                4.32           NaN                 NaN
# 1  Alabama 2021-06-02                5.15      0.192130            0.192130
# 2  Alabama 2021-06-03                5.39      0.046602            0.119366
# 3  Alabama 2021-06-04                6.35      0.178108            0.138946
# 4  Alabama 2021-06-05                6.35      0.000000            0.104210
#
#   State_code
# 0         AL
# 1         AL
# 2         AL
# 3         AL
# 4         AL

# %% [markdown]
# <h1>df_avg: 7-day average sentiment for each state
# </h1>

# %%
a = bq_df(dataframe)
a['date'] = pd.to_datetime(a['date'])
df = a.groupby('location').apply(lambda x: x.set_index('date').resample('1D').first())
# average sentiment of past seven days 
df_avg = df.groupby(level=0)['polarity'].apply(lambda x: x.shift().rolling(min_periods=1,window=7).mean()).reset_index(name='Value_Average_Past_7_days')
df_avg.head(10)
# Out:
#   location       date  Value_Average_Past_7_days
# 0  Alabama 2021-05-26                        NaN
# 1  Alabama 2021-05-27                   0.081363
# 2  Alabama 2021-05-28                  -0.025708
# 3  Alabama 2021-05-29                  -0.066778
# 4  Alabama 2021-05-30                  -0.021070
# 5  Alabama 2021-05-31                  -0.063659
# 6  Alabama 2021-06-01                  -0.077973
# 7  Alabama 2021-06-02                  -0.067517
# 8  Alabama 2021-06-03                  -0.102934
# 9  Alabama 2021-06-04                  -0.070535

# %% [markdown]
# <h1>df_avg_pct_ch: 7-day average of sentiment pct_change for each state
# </h1>

# %%
# df_avg_pct_ch includes average 7-day average of sentiment pct_change 
df['pct_ch'] = df['polarity'].pct_change()
df_avg_pct_ch = df.groupby(level=0)['pct_ch'].apply(lambda x: x.shift().rolling(min_periods=1,window=7).mean()).reset_index(name='pct_ch_Average_Past_7_days')
df_avg_pct_ch.head(10)
# Out:
#   location       date  pct_ch_Average_Past_7_days
# 0  Alabama 2021-05-26                         NaN
# 1  Alabama 2021-05-27                         NaN
# 2  Alabama 2021-05-28                   -2.631943
# 3  Alabama 2021-05-29                   -1.255200
# 4  Alabama 2021-05-30                   -1.429907
# 5  Alabama 2021-05-31                   -1.826539
# 6  Alabama 2021-06-01                   -1.533426
# 7  Alabama 2021-06-02                   -1.439195
# 8  Alabama 2021-06-03                    3.601432
# 9  Alabama 2021-06-04                    3.753926

# %%
# test out correlation of sentiment vs case 
# corr, p_value = pearsonr(x, y)

# find cases_avg_per_100k for Alabama 
mask_case = (df_June['state'] == 'Nevada')
df_June_case = df_June.loc[mask_case].cases_avg_per_100k.to_numpy()
# print(len(df_June_case))

# find senti for Alabama
mask_senti = (df_avg['location'] == 'Nevada') & (df_avg['date'] >= '2021-6-1') & (df_avg['date'] <= '2021-6-30')
df_June_senti = df_avg.loc[mask_senti].Value_Average_Past_7_days.to_numpy()
# print(len(df_June_senti))

# corr, p_value = pearsonr(df_June_case, df_June_senti)
# corr

# print("In sentiment df, we have", len(df_avg['location'].unique()), "states")
# print("In case df, we have", len(df_June['state'].unique()), "states")
# print(df_June['state'].unique())
# print(df_June['state'].unique())

# %% [markdown]
# <h1>Correlation between 7-day average cases per 100k and 7-day average sentiment
# </h1>

# %%
# calculate the pearson correlation 

# align the state column of two df 
# df_June['state'] = df_June['state'].apply(lambda state : state[0]+state[1:].lower())
df_June = df_June[['state', 'date', 'cases_avg_per_100k']].reset_index()
df_avg = df_avg.rename(columns={'location': 'state'})

all_in_one = df_June.merge(df_avg, on=['state', 'date'])
corr = all_in_one.groupby('state').apply(lambda x: pearsonr(x['cases_avg_per_100k'].to_numpy(), x['Value_Average_Past_7_days'].to_numpy())[0]).reset_index()
corr = corr.rename(columns={0: 'corr'})
corr.mean()
# Out:
# corr   -0.040705
# dtype: float64

# %% [markdown]
# <h1>Correlation Distribution
# </h1>

# %%
import matplotlib.pyplot as plt
plt.hist(np.array(corr['corr']), density=True, bins=8)
plt.ylabel('Count')
plt.xlabel('Correlation')
plt.title('Correlation Distribution')
# Out:
# Text(0.5, 1.0, 'Correlation Distribution')

# %% [markdown]
# <h1>Visualization: 7-day average Sentiment in June
# </h1>

# %%
# df_J contains Value_Average_Past_7_days in June 
df_avg["State_code"] = df_avg["state"].apply(lambda x: r_dic[x])
notwant = ['2021-05-26', '2021-05-27', '2021-05-28', '2021-05-29', '2021-05-30', '2021-05-31']
df_J = df_avg.loc[~df_avg['date'].isin(notwant)]
df_J['Value_Average_Past_7_days'] = df_J['Value_Average_Past_7_days'].round(5)
df_J.head(5)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       state       date  Value_Average_Past_7_days State_code
# 6   Alabama 2021-06-01                   -0.07797         AL
# 7   Alabama 2021-06-02                   -0.06752         AL
# 8   Alabama 2021-06-03                   -0.10293         AL
# 9   Alabama 2021-06-04                   -0.07053         AL
# 10  Alabama 2021-06-05                   -0.02069         AL

# %%
# 7-day average Sentiment in June 

### colorscale:    
scl = [[0.0, '#ffffff'],[0.2, '#b4a8ce'],[0.4, '#8573a9'],
       [0.6, '#7159a3'],[0.8, '#5732a1'],[1.0, '#2c0579']] # purples

### create empty list for data object:    
data_slider = []

#### I populate the data object
for date in df_J.date.unique():

    # I select the date (and remove DC for now)
    df_date = df_J[(df_J['state']!= 'District of Columbia' ) &  (df_J['date']== date )]

    for col in df_date.columns:  # I transform the columns into string type so I can:
        df_date[col] = df_date[col].astype(str)

    ### I create the text for mouse-hover for each state, for the current date    
    df_date['text'] = df_date['state'] + ' sentiment: ' + df_date['Value_Average_Past_7_days']

    ### create the dictionary with the data for the current year
    data_one_date = dict(
                        type='choropleth',
                        locations = df_date['State_code'],
                        z=df_date['Value_Average_Past_7_days'].astype(float),
                        locationmode='USA-states',
                        colorscale = scl,
                        text = df_date['text'],
                        colorbar = dict(
                        title = "Average 7 day sentiment")
                        )
    data_slider.append(data_one_date)  # I add the dictionary to the list of dictionaries for the slider

##  I create the steps for the slider
steps = []
for i in range(len(data_slider)):
    step = dict(method='restyle',
                args=['visible', [False] * len(data_slider)],
                label='Date {}'.format(i+1)) # label to be displayed for each step (year)
    step['args'][1][i] = True
    steps.append(step)

##  I create the 'sliders' object from the 'steps' 
sliders = [dict(active=0, pad={"t": 1}, steps=steps)]  

# I set up the layout (including slider option)
layout = dict(title = 'Average 7-day Sentiment on Covid-19 Protection Measures in June',
              geo=dict(scope='usa',
              projection={'type': 'albers usa'}),
              sliders=sliders)

# I create the figure object:
fig = dict(data=data_slider, layout=layout) 

# to plot in the notebook
plotly.offline.iplot(fig)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="286dd66e-696a-47f9-96c4-fd11fc5f3f43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("286dd66e-696a-47f9-96c4-fd11fc5f3f43")) {                    Plotly.newPlot(                        "286dd66e-696a-47f9-96c4-fd11fc5f3f43",                        [{"colorbar":{"title":{"text":"Average 7 day sentiment"}},"colorscale":[[0.0,"#ffffff"],[0.2,"#b4a8ce"],[0.4,"#8573a9"],[0.6,"#7159a3"],[0.8,"#5732a1"],[1.0,"#2c0579"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"text":["Alabama sentiment: -0.07797","Alaska sentiment: -0.07307","Arizona sentiment: -0.02651","Arkansas sentiment: 0.02935","California sentiment: 0.00691","Colorado sentiment: -0.01186","Connecticut sentiment: 0.11769","Delaware sentiment: 0.08368","Florida sentiment: -0.0483","Georgia sentiment: -0.07871","Hawaii sentiment: -0.02405","Idaho sentiment: 0.00152","Illinois sentiment: -0.01626","Indiana sentiment: -0.06141","Iowa sentiment: -0.16092","Kansas sentiment: 0.05877","Kentucky sentiment: -0.09733","Louisiana sentiment: -0.00605","Maine sentiment: 0.03227","Maryland sentiment: -0.01355","Massachusetts sentiment: 0.04338","Michigan sentiment: -0.05375","Minnesota sentiment: -0.06086","Mississippi sentiment: -0.0171","Missouri sentiment: -0.02122","Montana sentiment: 0.01438","Nebraska sentiment: -0.0323","Nevada sentiment: -0.06435","New Hampshire sentiment: 0.15177","New Jersey sentiment: 0.01583","New Mexico sentiment: -0.13326","New York sentiment: 8e-05","North Carolina sentiment: -0.02951","North Dakota sentiment: 0.21995","Ohio sentiment: -0.0266","Oklahoma sentiment: -0.1588","Oregon sentiment: 0.02213","Pennsylvania sentiment: 0.00588","Puerto Rico sentiment: -0.02828","Rhode Island sentiment: -0.20961","South Carolina sentiment: -0.09258","South Dakota sentiment: 0.21509","Tennessee sentiment: -0.076","Texas sentiment: -0.0722","Utah sentiment: 0.03441","Vermont sentiment: 0.23038","Virginia sentiment: -0.04552","Washington sentiment: -0.01182","West Virginia sentiment: 0.01988","Wisconsin sentiment: -0.06085","Wyoming sentiment: -0.07404"],"z":[-0.07797,-0.07307,-0.02651,0.02935,0.00691,-0.01186,0.11769,0.08368,-0.0483,-0.07871,-0.02405,0.00152,-0.01626,-0.06141,-0.16092,0.05877,-0.09733,-0.00605,0.03227,-0.01355,0.04338,-0.05375,-0.06086,-0.0171,-0.02122,0.01438,-0.0323,-0.06435,0.15177,0.01583,-0.13326,8e-05,-0.02951,0.21995,-0.0266,-0.1588,0.02213,0.00588,-0.02828,-0.20961,-0.09258,0.21509,-0.076,-0.0722,0.03441,0.23038,-0.04552,-0.01182,0.01988,-0.06085,-0.07404],"type":"choropleth"},{"colorbar":{"title":{"text":"Average 7 day sentiment"}},"colorscale":[[0.0,"#ffffff"],[0.2,"#b4a8ce"],[0.4,"#8573a9"],[0.6,"#7159a3"],[0.8,"#5732a1"],[1.0,"#2c0579"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"text":["Alabama sentiment: -0.06752","Alaska sentiment: -0.05829","Arizona sentiment: -0.03296","Arkansas sentiment: 0.01077","California sentiment: 0.00546","Colorado sentiment: -0.01041","Connecticut sentiment: 0.11002","Delaware sentiment: 0.04518","Florida sentiment: -0.04155","Georgia sentiment: -0.06619","Hawaii sentiment: -0.03968","Idaho sentiment: -0.02655","Illinois sentiment: -0.00925","Indiana sentiment: -0.04055","Iowa sentiment: -0.11262","Kansas sentiment: 0.05695","Kentucky  ...

# %% [markdown]
# <h1>Visualization: 7-day average cases per 100k in June
# </h1>

# %%
# Cases

### colorscale:    
scl = [[0.0, '#ffffff'],[0.2, '#ff9999'],[0.4, '#ff4d4d'], \
       [0.6, '#ff1a1a'],[0.8, '#cc0000'],[1.0, '#4d0000']] # reds

### create empty list for data object:    
data_slider = []

#### I populate the data object
for date in df_June_pct_ch.date.unique():

    # I select the date (and remove DC for now)
    df_date = df_June_pct_ch[(df_June_pct_ch['state']!= 'District of Columbia' ) &  (df_June_pct_ch['date']== date )]

    for col in df_date.columns:  # I transform the columns into string type so I can:
        df_date[col] = df_date[col].astype(str)

    ### I create the text for mouse-hover for each state, for the current date    
    df_date['text'] = df_date['state'] + ' cases_avg_per_100k: ' + df_date['cases_avg_per_100k']

    ### create the dictionary with the data for the current year
    data_one_date = dict(
                        type='choropleth',
                        locations = df_date['State_code'],
                        z=df_date['cases_avg_per_100k'].astype(float),
                        locationmode='USA-states',
                        colorscale = scl,
                        text = df_date['text'],
                        colorbar = dict(
                        title = "Cases_avg_per_100k")
                        )

    data_slider.append(data_one_date)  # I add the dictionary to the list of dictionaries for the slider

##  I create the steps for the slider
steps = []
for i in range(len(data_slider)):
    step = dict(method='restyle',
                args=['visible', [False] * len(data_slider)],
                label='Date {}'.format(i+1)) # label to be displayed for each step (year)
    step['args'][1][i] = True
    steps.append(step)

##  I create the 'sliders' object from the 'steps' 
sliders = [dict(active=0, pad={"t": 1}, steps=steps)]  

# I set up the layout (including slider option)
layout = dict(title = 'Cases_avg_per_100k in June',
              geo=dict(scope='usa',
              projection={'type': 'albers usa'}),
              sliders=sliders)

# I create the figure object:
fig = dict(data=data_slider, layout=layout) 

# to plot in the notebook
plotly.offline.iplot(fig)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="7c8952f6-861f-4a16-a5ea-537cf9fa6292" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c8952f6-861f-4a16-a5ea-537cf9fa6292")) {                    Plotly.newPlot(                        "7c8952f6-861f-4a16-a5ea-537cf9fa6292",                        [{"colorbar":{"title":{"text":"Cases_avg_per_100k"}},"colorscale":[[0.0,"#ffffff"],[0.2,"#ff9999"],[0.4,"#ff4d4d"],[0.6,"#ff1a1a"],[0.8,"#cc0000"],[1.0,"#4d0000"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"text":["Alabama cases_avg_per_100k: 4.32","Alaska cases_avg_per_100k: 5.1","Arizona cases_avg_per_100k: 7.4","Arkansas cases_avg_per_100k: 4.43","California cases_avg_per_100k: 2.55","Colorado cases_avg_per_100k: 10.75","Connecticut cases_avg_per_100k: 2.69","Delaware cases_avg_per_100k: 6.03","Florida cases_avg_per_100k: 8.61","Georgia cases_avg_per_100k: 4.11","Hawaii cases_avg_per_100k: 3.85","Idaho cases_avg_per_100k: 6.08","Illinois cases_avg_per_100k: 6.11","Indiana cases_avg_per_100k: 6.71","Iowa cases_avg_per_100k: 2.71","Kansas cases_avg_per_100k: 2.42","Kentucky cases_avg_per_100k: 5.66","Louisiana cases_avg_per_100k: 6.82","Maine cases_avg_per_100k: 7.3","Maryland cases_avg_per_100k: 3.16","Massachusetts cases_avg_per_100k: 3.18","Michigan cases_avg_per_100k: 6.13","Minnesota cases_avg_per_100k: 5.17","Mississippi cases_avg_per_100k: 4.05","Missouri cases_avg_per_100k: 6.37","Montana cases_avg_per_100k: 6.28","Nebraska cases_avg_per_100k: 3.1","Nevada cases_avg_per_100k: 5.75","New Hampshire cases_avg_per_100k: 3.56","New Jersey cases_avg_per_100k: 3.07","New Mexico cases_avg_per_100k: 5.08","New York cases_avg_per_100k: 4.17","North Carolina cases_avg_per_100k: 6.06","North Dakota cases_avg_per_100k: 4.69","Ohio cases_avg_per_100k: 4.84","Oklahoma cases_avg_per_100k: 3.13","Oregon cases_avg_per_100k: 7.77","Pennsylvania cases_avg_per_100k: 6.06","Puerto Rico cases_avg_per_100k: 2.84","Rhode Island cases_avg_per_100k: 4.61","South Carolina cases_avg_per_100k: 5.26","South Dakota cases_avg_per_100k: 4.02","Tennessee cases_avg_per_100k: 3.47","Texas cases_avg_per_100k: 3.3","Utah cases_avg_per_100k: 6.56","Vermont cases_avg_per_100k: 2.01","Virginia cases_avg_per_100k: 3.08","Washington cases_avg_per_100k: 12.06","West Virginia cases_avg_per_100k: 10.13","Wisconsin cases_avg_per_100k: 3.57","Wyoming cases_avg_per_100k: 12.19"],"z":[4.32,5.1,7.4,4.43,2.55,10.75,2.69,6.03,8.61,4.11,3.85,6.08,6.11,6.71,2.71,2.42,5.66,6.82,7.3,3.16,3.18,6.13,5.17,4.05,6.37,6.28,3.1,5.75,3.56,3.07,5.08,4.17,6.06,4.69,4.84,3.13,7.77,6.06,2.84,4.61,5.26,4.02,3.47,3.3,6.56,2.01,3.08,12.06,10.13,3.57,12.19],"type":"choropleth"},{"colorbar":{"title":{"text":"Cases_avg_per_100k"}},"colorscale":[[0.0,"#ffffff"],[0.2,"#ff9999"],[0.4,"#ff4d4d"],[0.6,"#ff1a1a"],[0.8,"#cc0000"],[1.0,"#4d0000"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"text":["Alabama cases_avg_per_100k: 5.15","Alaska cases_avg_per_100k: 4.51","Arizona cases_avg_per_100k: 7.91","Arkansas cases_avg_per_100k: 4.71","California cases_avg_per_100k: 2.42","Colorado cases_avg_per_100k: 10.09","Connecticut cases_avg_per_100k: 2.8","Delaware cases_avg_per_100k: 5.56","Florida cases_avg_per_100k: 7.88","Georgia cases_avg_per_100k: 4.02","Hawaii cases_avg_per_100k: 3.6" ...

# %% [markdown]
# <h1>Virtualization: correlation between 7-day average cases per 100k and 7-day average sentiment
# </h1>

# %%
# corr adding state code 
corr["State_code"] = corr["state"].apply(lambda x: r_dic[x])

df_corr = corr[(corr['state']!= 'District of Columbia' )]

scl =  [[0.0, '#f0f9e8'],[0.2, '#ccebc5'],[0.4, '#a8ddb5'],
       [0.6, '#7bccc4'],[0.8, '#43a2ca'],[1.0, '#0868ac']] # blue

for col in df_corr.columns:
    df_corr[col] = df_corr[col].astype(str)

df_corr['text'] = df_corr['state']+'Corr: '+df_corr['corr']

data = [ dict(
            type='choropleth', # type of map-plot
            colorscale = scl,
            autocolorscale = False,
            locations = df_corr['State_code'], # the column with the state
            z = df_corr['corr'].astype(float), # the variable I want to color-code
            locationmode = 'USA-states',
            text = df_corr['text'], # hover text
            marker = dict(     # for the lines separating states
                        line = dict (
                                  color = 'rgb(255,255,255)', 
                                  width = 2) ),               
            colorbar = dict(
                        title = "Correlation")
            ) 
       ]

layout = dict(
        title = 'Correlation: cases_avg_per_100k vs avg_sentiment in June',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            ),
             )

fig = dict( data=data, layout=layout )

plotly.offline.iplot(fig)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="88a4b82d-7ce7-4fc5-a393-6f630ccf17af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88a4b82d-7ce7-4fc5-a393-6f630ccf17af")) {                    Plotly.newPlot(                        "88a4b82d-7ce7-4fc5-a393-6f630ccf17af",                        [{"autocolorscale":false,"colorbar":{"title":{"text":"Correlation"}},"colorscale":[[0.0,"#f0f9e8"],[0.2,"#ccebc5"],[0.4,"#a8ddb5"],[0.6,"#7bccc4"],[0.8,"#43a2ca"],[1.0,"#0868ac"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"marker":{"line":{"color":"rgb(255,255,255)","width":2}},"text":["AlabamaCorr: 0.35843914037591706","AlaskaCorr: -0.37307678062448724","ArizonaCorr: -0.48000071264841465","ArkansasCorr: 0.2457467893719807","CaliforniaCorr: 0.07285887596167231","ColoradoCorr: 0.7142249423756576","ConnecticutCorr: 0.3530511433799214","DelawareCorr: 0.23757399468925006","FloridaCorr: -0.7008270179296505","GeorgiaCorr: -0.19992246399619162","HawaiiCorr: -0.36918266321063675","IdahoCorr: 0.2093974478760025","IllinoisCorr: -0.013713080431940916","IndianaCorr: -0.5288454689466847","IowaCorr: -0.2741234573430862","KansasCorr: 0.16070039586530654","KentuckyCorr: -0.5785138852338227","LouisianaCorr: -0.1680454778105908","MaineCorr: -0.3889709568510218","MarylandCorr: -0.25991639041574666","MassachusettsCorr: -0.15192271674496696","MichiganCorr: 0.3367507005083332","MinnesotaCorr: -0.4538146743649981","MississippiCorr: 0.30606366490684367","MissouriCorr: -0.6898640791367054","MontanaCorr: 0.5273622075395967","NebraskaCorr: 0.14689576866926607","NevadaCorr: 0.12937171249793894","New HampshireCorr: 0.5044798151901491","New JerseyCorr: -0.12735663711546164","New MexicoCorr: -0.33651776577067694","New YorkCorr: -0.14655436488879875","North CarolinaCorr: -0.19683815164573215","North DakotaCorr: 0.07224250418021987","OhioCorr: 0.2783017347621491","OklahomaCorr: 0.12222784712799692","OregonCorr: 0.39324579029896123","PennsylvaniaCorr: 0.286273397592828","Puerto RicoCorr: -0.6052791158340372","Rhode IslandCorr: -0.3351155248748792","South CarolinaCorr: -0.4924646522386237","South DakotaCorr: 0.7521968884674255","TennesseeCorr: -0.5068250397742399","TexasCorr: 0.3942736582546579","UtahCorr: -0.32523865614883957","VermontCorr: 0.8183266008781971","VirginiaCorr: -0.5177384768559435","WashingtonCorr: 0.22634272995887703","West VirginiaCorr: -0.7242291601488182","WisconsinCorr: -0.29430635678676564","WyomingCorr: -0.1713468563646775"],"z":[0.35843914037591706,-0.37307678062448724,-0.48000071264841465,0.2457467893719807,0.07285887596167231,0.7142249423756576,0.3530511433799214,0.23757399468925006,-0.7008270179296505,-0.19992246399619162,-0.36918266321063675,0.2093974478760025,-0.013713080431940916,-0.5288454689466847,-0.2741234573430862,0.16070039586530654,-0.5785138852338227,-0.1680454778105908,-0.3889709568510218,-0.25991639041574666,-0.15192271674496696,0.3367507005083332,-0.4538146743649981,0.30606366490684367,-0.6898640791367054,0.5273622075395967,0.14689576866926607,0.12937171249793894,0.5044798151901491,-0.12735663711546164,-0.33651776577067694,-0.14655436488879875,-0.19683815164573215,0.07224250418021987,0.2783017347621491,0.12222784712799692,0.39324579029896123,0.286273397592828,-0.6052791158340372,-0.3351155248748792,-0.4924646522386237,0.7521968884674255,-0.5068250397742399,0.3942736582546579,-0.32523865614883957,0.8183266008781971,-0.5177384768559435,0.22634272995887703,-0.7242291601488182,-0.29430635678676564,-0.1713468563646775],"type":"choropleth"}],                 ...

# %%
# df_June = df_June[['state', 'date', 'cases_avg_per_100k']].reset_index()
df_avg_pct_ch = df_avg_pct_ch.rename(columns={'location': 'state'})
all_in_one_ch = df_June_pct_ch.merge(df_avg_pct_ch, on=['state', 'date'])
# calculate the pearson correlation 
all_in_one_ch.replace([np.inf, -np.inf], np.nan, inplace=True)
all_in_one_ch = all_in_one_ch.dropna().reset_index()
corr_pct = all_in_one_ch.groupby('state').apply(lambda x: pearsonr(x['pct_ch_case_7_days'].to_numpy(), x['pct_ch_Average_Past_7_days'].to_numpy())[0]).reset_index()
corr_pct = corr_pct.rename(columns={0: 'corr'})
corr_pct.mean()
# Out:
# corr    0.028479
# dtype: float64

# %%
df_avg_pct_ch["State_code"] = df_avg_pct_ch["state"].apply(lambda x: r_dic[x])
notwant = ['2021-05-26', '2021-05-27', '2021-05-28', '2021-05-29', '2021-05-30', '2021-05-31']
df_J = df_avg_pct_ch.loc[~df_avg_pct_ch['date'].isin(notwant)]
df_J['pct_ch_Average_Past_7_days'] = df_J['pct_ch_Average_Past_7_days'].round(5)
df_J.head(5)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       state       date  pct_ch_Average_Past_7_days State_code
# 6   Alabama 2021-06-01                    -1.53343         AL
# 7   Alabama 2021-06-02                    -1.43919         AL
# 8   Alabama 2021-06-03                     3.60143         AL
# 9   Alabama 2021-06-04                     3.75393         AL
# 10  Alabama 2021-06-05                     3.89753         AL

# %% [markdown]
# <h1>Pct-change Correlation Distribution
# </h1>

# %%
import matplotlib.pyplot as plt
plt.hist(np.array(corr_pct['corr']), density=True, bins=8)
plt.ylabel('Count')
plt.xlabel('Correlation')
plt.title('Correlation Distribution')
# Out:
# Text(0.5, 1.0, 'Correlation Distribution')

# %% [markdown]
# <h1>Visulization: 7-day average of sentiment pct change
# </h1>

# %%
# 7-day average of Sentiment pct change  

### colorscale:    
scl = [[0.0, '#ffffff'],[0.2, '#b4a8ce'],[0.4, '#8573a9'],
       [0.6, '#7159a3'],[0.8, '#5732a1'],[1.0, '#2c0579']] # purples

### create empty list for data object:    
data_slider = []

#### I populate the data object
for date in df_J.date.unique():

    # I select the date (and remove DC for now)
    df_date = df_J[(df_J['state']!= 'District of Columbia' ) &  (df_J['date']== date )]

    for col in df_date.columns:  # I transform the columns into string type so I can:
        df_date[col] = df_date[col].astype(str)

    ### I create the text for mouse-hover for each state, for the current date    
    df_date['text'] = df_date['state'] + ' 7-day avg sentiment pct change: ' + df_date['pct_ch_Average_Past_7_days']

    ### create the dictionary with the data for the current year
    data_one_date = dict(
                        type='choropleth',
                        locations = df_date['State_code'],
                        z=df_date['pct_ch_Average_Past_7_days'].astype(float),
                        locationmode='USA-states',
                        colorscale = scl,
                        text = df_date['text'],
                        colorbar = dict(
                        title = "7-day avg sentiment pct change")
                        )
    data_slider.append(data_one_date)  # I add the dictionary to the list of dictionaries for the slider

##  I create the steps for the slider
steps = []
for i in range(len(data_slider)):
    step = dict(method='restyle',
                args=['visible', [False] * len(data_slider)],
                label='Date {}'.format(i+1)) # label to be displayed for each step (year)
    step['args'][1][i] = True
    steps.append(step)


##  I create the 'sliders' object from the 'steps' 
sliders = [dict(active=0, pad={"t": 1}, steps=steps)]  

# I set up the layout (including slider option)
layout = dict(title = '7-day avg sentiment pct change on Covid-19 Protection Measures in June',
              geo=dict(scope='usa',
              projection={'type': 'albers usa'}),
              sliders=sliders)

# I create the figure object:
fig = dict(data=data_slider, layout=layout) 

# to plot in the notebook
plotly.offline.iplot(fig)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="6255e1c1-7e5f-4adf-9097-728c222fc964" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6255e1c1-7e5f-4adf-9097-728c222fc964")) {                    Plotly.newPlot(                        "6255e1c1-7e5f-4adf-9097-728c222fc964",                        [{"colorbar":{"title":{"text":"7-day avg sentiment pct change"}},"colorscale":[[0.0,"#ffffff"],[0.2,"#b4a8ce"],[0.4,"#8573a9"],[0.6,"#7159a3"],[0.8,"#5732a1"],[1.0,"#2c0579"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"text":["Alabama 7-day avg sentiment pct change: -1.53343","Alaska 7-day avg sentiment pct change: -1.01903","Arizona 7-day avg sentiment pct change: -0.48927","Arkansas 7-day avg sentiment pct change: -2.25056","California 7-day avg sentiment pct change: -0.47602","Colorado 7-day avg sentiment pct change: -0.95008","Connecticut 7-day avg sentiment pct change: -2.11545","Delaware 7-day avg sentiment pct change: -1.54779","Florida 7-day avg sentiment pct change: -1.87769","Georgia 7-day avg sentiment pct change: 1.34025","Hawaii 7-day avg sentiment pct change: -0.95802","Idaho 7-day avg sentiment pct change: -1.81029","Illinois 7-day avg sentiment pct change: -2.21014","Indiana 7-day avg sentiment pct change: 2.13543","Iowa 7-day avg sentiment pct change: -8.05336","Kansas 7-day avg sentiment pct change: 1.44373","Kentucky 7-day avg sentiment pct change: -1.56367","Louisiana 7-day avg sentiment pct change: 12.55597","Maine 7-day avg sentiment pct change: -0.57191","Maryland 7-day avg sentiment pct change: -0.40486","Massachusetts 7-day avg sentiment pct change: 1.45494","Michigan 7-day avg sentiment pct change: -3.7724","Minnesota 7-day avg sentiment pct change: -0.89973","Mississippi 7-day avg sentiment pct change: -1.35163","Missouri 7-day avg sentiment pct change: 38.28329","Montana 7-day avg sentiment pct change: -0.48523","Nebraska 7-day avg sentiment pct change: -2.45381","Nevada 7-day avg sentiment pct change: -0.54615","New Hampshire 7-day avg sentiment pct change: -0.79465","New Jersey 7-day avg sentiment pct change: -1.47122","New Mexico 7-day avg sentiment pct change: -0.08896","New York 7-day avg sentiment pct change: -1.18834","North Carolina 7-day avg sentiment pct change: -3.67989","North Dakota 7-day avg sentiment pct change: 2.74702","Ohio 7-day avg sentiment pct change: -1.95025","Oklahoma 7-day avg sentiment pct change: 1.21639","Oregon 7-day avg sentiment pct change: -0.65468","Pennsylvania 7-day avg sentiment pct change: -1.11118","Puerto Rico 7-day avg sentiment pct change: -2.31926","Rhode Island 7-day avg sentiment pct change: 2.00105","South Carolina 7-day avg sentiment pct change: -4.54911","South Dakota 7-day avg sentiment pct change: 0.08769","Tennessee 7-day avg sentiment pct change: -0.499","Texas 7-day avg sentiment pct change: 0.40981","Utah 7-day avg sentiment pct change: -0.89191","Vermont 7-day avg sentiment pct change: -3.32996","Virginia 7-day avg sentiment pct change: -1.19817","Washington 7-day avg sentiment pct change: -1.34119","West Virginia 7-day avg sentiment pct change: -0.22585","Wisconsin 7-day avg sentiment pct change: 99.05308","Wyoming 7-day avg sentiment pct change: -2.39326"],"z":[-1.53343,-1.01903,-0.48927,-2.25056,-0.47602,-0.95008,-2.11545,-1.54779,-1.87769,1.34025,-0.95802,-1.81029,-2.21014,2.13543,-8.05336,1.44373,-1.56367,12.55597,-0.57191,-0.40486,1.45494,-3.7724,-0.89973,-1.35163,38.28329,-0.48523,-2.45381,-0.54615,-0.79465,-1.47122,-0.08896,-1.18834,-3.67989,2.74702,-1.95025,1.21639,- ...

# %% [markdown]
# <h1>Visulization: 7-day average of cases_per_100k pct change
# </h1>

# %%
#  7-day average of cases_per_100k pct change  

### colorscale: 
scl = [[0.0, '#ffffff'],[0.2, '#ff9999'],[0.4, '#ff4d4d'], \
       [0.6, '#ff1a1a'],[0.8, '#cc0000'],[1.0, '#4d0000']] # reds


### create empty list for data object:    
data_slider = []

#### I populate the data object
for date in df_June_pct_ch.date.unique():

    # I select the date (and remove DC for now)
    df_date = df_June_pct_ch[(df_June_pct_ch['state']!= 'District of Columbia' ) &  (df_June_pct_ch['date']== date )]

    for col in df_date.columns:  # I transform the columns into string type so I can:
        df_date[col] = df_date[col].astype(str)

    ### I create the text for mouse-hover for each state, for the current date    
    df_date['text'] = df_date['state'] + ' 7-day-avg of cases_per_100k pct change  : ' + df_date['pct_ch_case_7_days']

    ### create the dictionary with the data for the current year
    data_one_date = dict(
                        type='choropleth',
                        locations = df_date['State_code'],
                        z=df_date['pct_ch_case_7_days'].astype(float),
                        locationmode='USA-states',
                        colorscale = scl,
                        text = df_date['text'],
                        colorbar = dict(
                        title = "7-day-avg of cases_per_100k pct change")
                        )
    data_slider.append(data_one_date)  # I add the dictionary to the list of dictionaries for the slider

##  I create the steps for the slider
steps = []
for i in range(len(data_slider)):
    step = dict(method='restyle',
                args=['visible', [False] * len(data_slider)],
                label='Date {}'.format(i+1)) # label to be displayed for each step (year)
    step['args'][1][i] = True
    steps.append(step)

##  I create the 'sliders' object from the 'steps' 
sliders = [dict(active=0, pad={"t": 1}, steps=steps)]  

# I set up the layout (including slider option)
layout = dict(title = '7-day-avg of cases_per_100k pct change in June',
              geo=dict(scope='usa',
              projection={'type': 'albers usa'}),
              sliders=sliders)

# I create the figure object:
fig = dict(data=data_slider, layout=layout) 

# to plot in the notebook
plotly.offline.iplot(fig)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="82751957-9f5b-460f-9b98-7990106e3e20" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82751957-9f5b-460f-9b98-7990106e3e20")) {                    Plotly.newPlot(                        "82751957-9f5b-460f-9b98-7990106e3e20",                        [{"colorbar":{"title":{"text":"7-day-avg of cases_per_100k pct change"}},"colorscale":[[0.0,"#ffffff"],[0.2,"#ff9999"],[0.4,"#ff4d4d"],[0.6,"#ff1a1a"],[0.8,"#cc0000"],[1.0,"#4d0000"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"text":["Alabama 7-day-avg of cases_per_100k pct change  : nan","Alaska 7-day-avg of cases_per_100k pct change  : nan","Arizona 7-day-avg of cases_per_100k pct change  : nan","Arkansas 7-day-avg of cases_per_100k pct change  : nan","California 7-day-avg of cases_per_100k pct change  : nan","Colorado 7-day-avg of cases_per_100k pct change  : nan","Connecticut 7-day-avg of cases_per_100k pct change  : nan","Delaware 7-day-avg of cases_per_100k pct change  : nan","Florida 7-day-avg of cases_per_100k pct change  : nan","Georgia 7-day-avg of cases_per_100k pct change  : nan","Hawaii 7-day-avg of cases_per_100k pct change  : nan","Idaho 7-day-avg of cases_per_100k pct change  : nan","Illinois 7-day-avg of cases_per_100k pct change  : nan","Indiana 7-day-avg of cases_per_100k pct change  : nan","Iowa 7-day-avg of cases_per_100k pct change  : nan","Kansas 7-day-avg of cases_per_100k pct change  : nan","Kentucky 7-day-avg of cases_per_100k pct change  : nan","Louisiana 7-day-avg of cases_per_100k pct change  : nan","Maine 7-day-avg of cases_per_100k pct change  : nan","Maryland 7-day-avg of cases_per_100k pct change  : nan","Massachusetts 7-day-avg of cases_per_100k pct change  : nan","Michigan 7-day-avg of cases_per_100k pct change  : nan","Minnesota 7-day-avg of cases_per_100k pct change  : nan","Mississippi 7-day-avg of cases_per_100k pct change  : nan","Missouri 7-day-avg of cases_per_100k pct change  : nan","Montana 7-day-avg of cases_per_100k pct change  : nan","Nebraska 7-day-avg of cases_per_100k pct change  : nan","Nevada 7-day-avg of cases_per_100k pct change  : nan","New Hampshire 7-day-avg of cases_per_100k pct change  : nan","New Jersey 7-day-avg of cases_per_100k pct change  : nan","New Mexico 7-day-avg of cases_per_100k pct change  : nan","New York 7-day-avg of cases_per_100k pct change  : nan","North Carolina 7-day-avg of cases_per_100k pct change  : nan","North Dakota 7-day-avg of cases_per_100k pct change  : nan","Ohio 7-day-avg of cases_per_100k pct change  : nan","Oklahoma 7-day-avg of cases_per_100k pct change  : nan","Oregon 7-day-avg of cases_per_100k pct change  : nan","Pennsylvania 7-day-avg of cases_per_100k pct change  : nan","Puerto Rico 7-day-avg of cases_per_100k pct change  : nan","Rhode Island 7-day-avg of cases_per_100k pct change  : nan","South Carolina 7-day-avg of cases_per_100k pct change  : nan","South Dakota 7-day-avg of cases_per_100k pct change  : nan","Tennessee 7-day-avg of cases_per_100k pct change  : nan","Texas 7-day-avg of cases_per_100k pct change  : nan","Utah 7-day-avg of cases_per_100k pct change  : nan","Vermont 7-day-avg of cases_per_100k pct change  : nan","Virginia 7-day-avg of cases_per_100k pct change  : nan","Washington 7-day-avg of cases_per_100k pct change  : nan","West Virginia 7-day-avg of cases_per_100k pct change  : nan","Wisconsin 7-day-avg of cases_per_100k pct change  : nan","Wyoming 7-day-avg of cases_per_100k pct change  : nan"],"z":[null,null,null,null,null,null,null,null,nul ...

# %% [markdown]
# <h1>Visualization: Correlation between 7-day average of sentiment pct change and 7-day average of cases_per_100k pct change
# </h1>

# %%
# corr
corr_pct["State_code"] = corr["state"].apply(lambda x: r_dic[x])

df_corr_pct = corr_pct[(corr_pct['state']!= 'District of Columbia' )]

scl =  [[0.0, '#f0f9e8'],[0.2, '#ccebc5'],[0.4, '#a8ddb5'],
       [0.6, '#7bccc4'],[0.8, '#43a2ca'],[1.0, '#0868ac']] # blue

for col in df_corr_pct.columns:
    df_corr_pct[col] = df_corr_pct[col].astype(str)

df_corr_pct['text'] = df_corr_pct['state']+'Corr: '+df_corr_pct['corr']

data = [ dict(
            type='choropleth', # type of map-plot
            colorscale = scl,
            autocolorscale = False,
            locations = df_corr_pct['State_code'], # the column with the state
            z = df_corr_pct['corr'].astype(float), # the variable I want to color-code
            locationmode = 'USA-states',
            text = df_corr_pct['text'], # hover text
            marker = dict(     # for the lines separating states
                        line = dict (
                                  color = 'rgb(255,255,255)', 
                                  width = 2) ),               
            colorbar = dict(
                        title = "Correlation")
            ) 
       ]

layout = dict(
        title = 'Correlation: cases_avg_per_100k pct change vs 7-day avg sentiment pct change in June',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            ),
             )

fig = dict( data=data, layout=layout )
plotly.offline.iplot(fig)
# Out:
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/yinxiuchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="00de7919-3bbc-4f78-a4aa-52b76a84bce8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00de7919-3bbc-4f78-a4aa-52b76a84bce8")) {                    Plotly.newPlot(                        "00de7919-3bbc-4f78-a4aa-52b76a84bce8",                        [{"autocolorscale":false,"colorbar":{"title":{"text":"Correlation"}},"colorscale":[[0.0,"#f0f9e8"],[0.2,"#ccebc5"],[0.4,"#a8ddb5"],[0.6,"#7bccc4"],[0.8,"#43a2ca"],[1.0,"#0868ac"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","PR","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"marker":{"line":{"color":"rgb(255,255,255)","width":2}},"text":["AlabamaCorr: 0.5926442104763063","AlaskaCorr: -0.16374875497667934","ArizonaCorr: 0.29569879869307747","ArkansasCorr: 0.4443730943123028","CaliforniaCorr: 0.06091319633720289","ColoradoCorr: -0.2869116156602509","ConnecticutCorr: -0.19653150599254454","DelawareCorr: -0.3145238033808544","FloridaCorr: 0.4073337453178227","GeorgiaCorr: 0.22584076966158192","HawaiiCorr: 0.3688887447417311","IdahoCorr: -0.2245112741199269","IllinoisCorr: -0.34864011902302683","IndianaCorr: 0.2233472102411043","IowaCorr: -0.7056370681554319","KansasCorr: 0.35799911831739195","KentuckyCorr: -0.012056151727514966","LouisianaCorr: 0.5304141914696163","MaineCorr: 0.03061446575991162","MarylandCorr: 0.08349689147064325","MassachusettsCorr: -0.194767743854742","MichiganCorr: 0.5420890382764935","MinnesotaCorr: -0.26913209806973937","MississippiCorr: 0.012377785578928047","MissouriCorr: -0.6156386860889806","MontanaCorr: 0.4532304476845429","NebraskaCorr: -0.005283932058537187","NevadaCorr: 0.0483134949119193","New HampshireCorr: 0.13501213273424933","New JerseyCorr: 0.29803544457902825","New MexicoCorr: 0.035634812682093356","New YorkCorr: 0.033544339084611394","North CarolinaCorr: 0.1785995897808525","North DakotaCorr: -0.07381332490515082","OhioCorr: -0.34637026143850147","OklahomaCorr: -0.0789026040701267","OregonCorr: -0.0012152712894266116","PennsylvaniaCorr: -0.405163741516433","Puerto RicoCorr: -0.5171794080275977","Rhode IslandCorr: -0.36521804263182667","South CarolinaCorr: 0.42832732256032596","South DakotaCorr: 0.03323612973453136","TennesseeCorr: 0.6051588080864287","TexasCorr: -0.1953830330910022","UtahCorr: 0.4930539126564664","VermontCorr: 0.1934317807531461","VirginiaCorr: 0.5176409664945684","WashingtonCorr: 0.02760769517941177","West VirginiaCorr: 0.1548003480706907","WisconsinCorr: -0.5183412791968875","WyomingCorr: -0.2648238700414338"],"z":[0.5926442104763063,-0.16374875497667934,0.29569879869307747,0.4443730943123028,0.06091319633720289,-0.2869116156602509,-0.19653150599254454,-0.3145238033808544,0.4073337453178227,0.22584076966158192,0.3688887447417311,-0.2245112741199269,-0.34864011902302683,0.2233472102411043,-0.7056370681554319,0.35799911831739195,-0.012056151727514966,0.5304141914696163,0.03061446575991162,0.08349689147064325,-0.194767743854742,0.5420890382764935,-0.26913209806973937,0.012377785578928047,-0.6156386860889806,0.4532304476845429,-0.005283932058537187,0.0483134949119193,0.13501213273424933,0.29803544457902825,0.035634812682093356,0.033544339084611394,0.1785995897808525,-0.07381332490515082,-0.34637026143850147,-0.0789026040701267,-0.0012152712894266116,-0.405163741516433,-0.5171794080275977,-0.36521804263182667,0.42832732256032596,0.03323612973453136,0.6051588080864287,-0.1953830330910022,0.4930539126564664,0.1934317807531461,0.5176409664945684,0.02760769517941177,0.1548003480706907,-0.5183412791968875,-0.2648238700414338],"type":"choropleth"}],                   ...
